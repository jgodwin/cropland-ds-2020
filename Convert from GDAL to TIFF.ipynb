# %% [markdown]
# # Convert from GeoTiff to Numpy
# This script takes all of the GeoTIFF files, reads them using GDAL, converts them to numpy arrays, and then pre-processes the images and saves them to a more easily used format (compressed numpy arrays) so that we don't have to use GDAL all the time to load the data.

# %%
import gdal, common, uuid
from osgeo import gdal_array
import numpy as np
from io import BytesIO
from scipy.ndimage import rotate



ROTATION_ANGLE = 14 # determined by brute force

class Rotator:
    '''
    A simple wrapping class that can rotate images based on the rotation information derived from the label image.
    '''
    def __init__(self, labelImage, rotationAngle=ROTATION_ANGLE):
        self.labelImage = labelImage
        self.rotAngle = rotationAngle
        
        nl = np.array(labelImage[:,:,0])
        # 255 is the padding value for the rotated image, so set that to zero.
        nl[nl==255] = 0
        # use zero-order here because this is a nearest neighbor 
        nl = rotate(nl,self.rotAngle,order=0)

        # about half-way through the image find the first and last sample that are not zero, these define
        # the cropping extents for the rotated image, so that we can reduce our image to only the parts that
        # matter
        horz = np.where(abs(np.diff(nl[3000])) > 0)[0]
        vert = np.where(abs(np.diff(nl[:,3000])) > 0)[0]

        self.sx1,self.ex1 = horz[0],horz[-1]
        self.sy1,self.ey1 = vert[0],vert[-1]

        self.rotatedLabelImage = nl[self.sy1:self.ey1, self.sx1:self.ex1]
        
    def __call__(self, image):
        rotated = rotate(image,self.rotAngle, order=1) # this is linear
        return rotated[self.sy1:self.ey1, self.sx1:self.ex1]
    
    
def cleanLabelImage(rotator,nclasses=10):
    '''
    Extract the most significant classes from the label image, otherwise you wind up with a bunch of classes that
    only have very small counts, and subsequently you'll waste a lot of time trying to train a classifier using almost
    no training data for those classes.
    '''
    # there are 256 classes in the raw image
    classCounts = np.zeros((256,2))
    for k in range(0,255):
        rotClass = (rot.rotatedLabelImage == k).sum()
        origClass = (rot.labelImage == k).sum()
        classCounts[k,:] = [rotClass, origClass]
        print('Class count : {} -> {} {}'.format(k,rotClass,origClass))

    print('there are {} classes with non-zero counts'.format((classCounts[:,0] > 0).sum()))
#     np.histogram(classCounts[:,0],bins=100)
    idx = np.argsort(classCounts[:,0])[::-1] # descending order argsort
    keepClasses = classCounts[idx,0][:nclasses]
    remappedLabelImage = np.zeros_like(rot.rotatedLabelImage)
    keepCount = 1
    for clazz, count in zip(idx,keepClasses):
        swap = rot.rotatedLabelImage == clazz
#         print('swap.sum', swap.sum())
        remappedLabelImage[swap] = keepCount
#         print(clazz, count, keepCount)
        keepCount += 1
    print('the min,max range of the remapped label image is: {}, {}'.format(remappedLabelImage.min(), remappedLabelImage.max()))
    return remappedLabelImage

def cleanSpectralImage(image,thresh=20000):
    '''
    There are anomalously large values in some of the bands, we need to clamp those values to prevent them from causing problems.
    '''
    cleaned = np.array(image)
#     pclip = np.percentile(cleaned,95)
    cleaned[image > thresh] = thresh
    return cleaned

def geoToArray(gdalImage):
    '''
    Convert a gdal image to a corresponding numpy array.
    '''
    #>>>>>>>> This particular segment of code was refactored from: https://github.com/bhavesh907/Crop-Classification/blob/master/data-preprocessing.ipynb
    shape = (gdalImage.RasterYSize, gdalImage.RasterXSize, gdalImage.RasterCount)
    image = np.zeros(shape,
               gdal_array.GDALTypeCodeToNumericTypeCode(gdalImage.GetRasterBand(1).DataType))

    for b in range(1,shape[2]+1):
        image[:, :, b-1] = gdalImage.GetRasterBand(b).ReadAsArray()
        
    #<<<<<<<<<'
    return image

def info(dataset):
    '''
    This was an attempt to backout the rotation directly inside of GDAL, but it was taking too long to figure out so I abandoned it
    and went ahead and just brute forced the rotation angle.
    '''
    print("Projection is {}".format(dataset.GetProjection()))
    geotransform = dataset.GetGeoTransform()
    if geotransform:
        print('geo transform', geotransform)
        print("Origin = ({}, {})".format(geotransform[0], geotransform[3]))
        print("Pixel Size = ({}, {})".format(geotransform[1], geotransform[5]))
        

                            
def readGeoTiff(key):
    '''
    Read geo tiff data from raw bytes, and convert to numpy arrays.
    '''
    # >>>> this particular code snippet was modified from: https://gist.github.com/jleinonen/5781308
    byteData = common.readTIFF(key)
    gdal_dataset = None
    try:
        mmap_name = "/vsimem/"+str(uuid.uuid4())
        gdal.FileFromMemBuffer(mmap_name, byteData)
        gdal_dataset = gdal.Open(mmap_name)
#         info(gdal_dataset)
        return geoToArray(gdal_dataset)
    finally:
        if gdal_dataset is not None:
            gdal_dataset = None
            gdal.Unlink(mmap_name)
    # <<<<<


images = {}

labelImage = readGeoTiff(common.LABEL_KEY)

rot = Rotator(labelImage)

labelImage = cleanLabelImage(rot)
common.saveNumpy(labelImage,'labels')
# Out:
# Class count : 0 -> 51584 6048
# Class count : 1 -> 51136 51120
# Class count : 2 -> 70224 70704
# Class count : 3 -> 0 0
# Class count : 4 -> 3087 3492
# Class count : 5 -> 0 0
# Class count : 6 -> 0 0
# Class count : 7 -> 0 0
# Class count : 8 -> 0 0
# Class count : 9 -> 0 0
# Class count : 10 -> 0 0
# Class count : 11 -> 0 0
# Class count : 12 -> 0 0
# Class count : 13 -> 0 0
# Class count : 14 -> 0 0
# Class count : 15 -> 0 0
# Class count : 16 -> 0 0
# Class count : 17 -> 0 0
# Class count : 18 -> 0 0
# Class count : 19 -> 0 0
# Class count : 20 -> 0 0
# Class count : 21 -> 46673 47700
# Class count : 22 -> 0 0
# Class count : 23 -> 870 864
# Class count : 24 -> 490124 494748
# Class count : 25 -> 0 0
# Class count : 26 -> 0 0
# Class count : 27 -> 0 0
# Class count : 28 -> 73417 73512
# Class count : 29 -> 0 0
# Class count : 30 -> 0 0
# Class count : 31 -> 0 0
# Class count : 32 -> 0 0
# Class count : 33 -> 5988 6120
# Class count : 34 -> 0 0
# Class count : 35 -> 0 0
# Class count : 36 -> 1540735 1543068
# Class count : 37 -> 23706 23724
# Class count : 38 -> 0 0
# Class count : 39 -> 0 0
# Class count : 40 -> 0 0
# Class count : 41 -> 0 0
# Class count : 42 -> 937 936
# Class count : 43 -> 0 0
# Class count : 44 -> 0 0
# Class count : 45 -> 0 0
# Class count : 46 -> 0 0
# Class count : 47 -> 0 0
# Class count : 48 -> 609 612
# Class count : 49 -> 37114 37476
# Class count : 50 -> 0 0
# Class count : 51 -> 0 0
# Class count : 52 -> 0 0
# Class count : 53 -> 0 0
# Class count : 54 -> 15137 15696
# Class count : 55 -> 0 0
# Class count : 56 -> 0 0
# Class count : 57 -> 146 144
# Class count : 58 -> 0 0
# Class count : 59 -> 2124 2124
# Class count : 60 -> 0 0
# Class count : 61 -> 378777 379464
# Class count : 62 -> 0 0
# Class count : 63 -> 0 0
# Class count : 64 -> 0 0
# Class count : 65 -> 0 0
# Class count : 66 -> 13460 13464
# Class count : 67 -> 8158 8208
# Class count : 68 -> 0 0
# Class count : 69 -> 8300189 8311968
# Class count : 70 -> 0 0
# Class count : 71 -> 4654 4644
# Class count : 72 -> 147 144
# Class count : 73 -> 0 0
# Class count : 74 -> 0 0
# Class count : 75 -> 4721173 4729104
# Class count : 76 -> 339901 340560
# Class count : 77 -> 1623 1620
# Class count : 78 -> 0 0
# Class count : 79 -> 0 0
# Class count : 80 -> 0 0
# Class count : 81 -> 0 0
# Class count : 82 -> 0 0
# Class count : 83 -> 0 0
# Class count : 84 -> 0 0
# Class count : 85 -> 0 0
# Class count : 86 -> 0 0
# Class count : 87 -> 0 0
# Class count : 88 -> 0 0
# Class count : 89 -> 0 0
# Class count : 90 -> 0 0
# Class count : 91 -> 0 0
# Class count : 92 -> 0 0
# Class count : 93 -> 0 0
# Class count : 94 -> 0 0
# Class count : 95 -> 0 0
# Class count : 96 -> 0 0
# Class count : 97 -> 0 0
# Class count : 98 -> 0 0
# Class count : 99 -> 0 0
# Class count : 100 -> 0 0
# Class count : 101 -> 0 0
# Class count : 102 -> 0 0
# Class count : 103 -> 0 0
# Class count : 104 -> 0 0
# Class count : 105 -> 0 0
# Class count : 106 -> 0 0
# Class count : 107 -> 0 0
# Class count : 108 -> 0 0
# Class count : 109 -> 0 0
# Class count : 110 -> 0 0
# Class count : 111 -> 148481 148788
# Class count : 112 -> 0 0
# Class count : 113 -> 0 0
# Class count : 114 -> 0 0
# Class count : 115 -> 0 0
# Class count : 116 -> 0 0
# Class count : 117 -> 0 0
# Class count : 118 -> 0 0
# Class count : 119 -> 0 0
# Class count : 120 -> 0 0
# Class count : 121 -> 754481 766044
# Class count : 122 -> 323087 331164
# Class count : 123 -> 134709 138420
# Class count : 124 -> 30559 31998
# Class count : 125 -> 0 0
# Class count : 126 -> 0 0
# Class count : 127 -> 0 0
# Class count : 128 -> 0 0
# Class count : 129 -> 0 0
# Class count : 130 -> 0 0
# Class count : 131 -> 37432 37512
# Class count : 132 -> 0 0
# Class count : 133 -> 0 0
# Class count : 134 -> 0 0
# Class count : 135 -> 0 0
# Class count : 136 -> 0 0
# Class count : 137 -> 0 0
# Class count : 138 -> 0 0
# Class count : 139 -> 0 0
# Class count : 140 -> 0 0
# Class count : 141 -> 0 0
# Class count : 142 -> 0 0
# Class count : 143 -> 0 0
# Class count : 144 -> 0 0
# Class count : 145 -> 0 0
# Class count : 146 -> 0 0
# Class count : 147 -> 0 0
# Class count : 148 -> 0 0
# Class count : 149 -> 0 0
# Class count : 150 -> 0 0
# Class count : 151 -> 0 0
# Class count : 152 -> 1082 1080
# Class count : 153 -> 0 0
# Class count : 154 -> 0 0
# Class count : 155 -> 0 0
# Class count : 156 -> 0 0
# Class count : 157 -> 0 0
# Class count : 158 -> 0 0
# Class count : 159 -> 0 0
# Class count : 160 -> 0 0
# Class count : 161 -> 0 0
# Class count : 162 -> 0 0
# Class count : 163 -> 0 0
# Class count : 164 -> 0 0
# Class count : 165 -> 0 0
# Class count : 166 -> 0 0
# Class count : 167 -> 0 0
# Class count : 168 -> 0 0
# Class count : 169 -> 0 0
# Class count : 170 -> 0 0
# Class count : 171 -> 0 0
# Class count : 172 -> 0 0
# Class count : 173 -> 0 0
# Class count : 174 -> 0 0
# Class count : 175 -> 0 0
# Class count : 176 -> 223215 225396
# Class count : 177 -> 0 0
# Class count : 178 -> 0 0
# Class count : 179 -> 0 0
# Class count : 180 -> 0 0
# Class count : 181 -> 0 0
# Class count : 182 -> 0 0
# Class count : 183 -> 0 0
# Class count : 184 -> 0 0
# Class count : 185 -> 0 0
# Class count : 186 -> 0 0
# Class count : 187 -> 0 0
# Class count : 188 -> 0 0
# Class count : 189 -> 0 0
# Class count : 190 -> 5894 5904
# Class count : 191 -> 0 0
# Class count : 192 -> 0 0
# Class count : 193 -> 0 0
# Class count : 194 -> 0 0
# Class count : 195 -> 7141 7164
# Class count : 196 -> 0 0
# Class count : 197 -> 0 0
# Class count : 198 -> 0 0
# Class count : 199 -> 0 0
# Class count : 200 -> 0 0
# Class count : 201 -> 0 0
# Class count : 202 -> 0 0
# Class count : 203 -> 0 0
# Class count : 204 -> 409151 410688
# Class count : 205 -> 8678 8640
# Class count : 206 -> 15823 16020
# Class count : 207 -> 0 0
# Class count : 208 -> 2148 2124
# Class count : 209 -> 649 648
# Class count : 210 -> 0 0
# Class count : 211 -> 0 0
# Class count : 212 -> 1401 1404
# Class count : 213 -> 723 720
# Class count : 214 -> 0 0
# Class count : 215 -> 0 0
# Class count : 216 -> 754 756
# Class count : 217 -> 22966 23004
# Class count : 218 -> 2155 2160
# Class count : 219 -> 0 0
# Class count : 220 -> 3416 3420
# Class count : 221 -> 0 0
# Class count : 222 -> 0 0
# Class count : 223 -> 0 0
# Class count : 224 -> 37 36
# Class count : 225 -> 615181 617040
# Class count : 226 -> 72 72
# Class count : 227 -> 2266 2448
# Class count : 228 -> 0 0
# Class count : 229 -> 0 0
# Class count : 230 -> 0 0
# Class count : 231 -> 0 0
# Class count : 232 -> 0 0
# Class count : 233 -> 0 0
# Class count : 234 -> 0 0
# Class count : 235 -> 0 0
# Class count : 236 -> 62066 62424
# Class count : 237 -> 14235 14292
# Class count : 238 -> 4700 4716
# Class count : 239 -> 0 0
# Class count : 240 -> 0 0
# Class count : 241 -> 0 0
# Class count : 242 -> 251 252
# Class count : 243 -> 0 0
# Class count : 244 -> 0 0
# Class count : 245 -> 0 0
# Class count : 246 -> 0 0
# Class count : 247 -> 0 0
# Class count : 248 -> 0 0
# Class count : 249 -> 0 0
# Class count : 250 -> 0 0
# Class count : 251 -> 0 0
# Class count : 252 -> 0 0
# Class count : 253 -> 0 0
# Class count : 254 -> 0 0
# there are 55 classes with non-zero counts
# the min,max range of the remapped label image is: 0, 10

# %%
import tqdm

for key in tqdm.tqdm(common.IMAGE_KEYS):
    im = readGeoTiff(key)
    rotated = rot(im)
    finalIm = cleanSpectralImage(rotated)
    common.saveNumpy(finalIm, key.split('.')[0]) # strip the extension
# Out:
# 100%|██████████| 10/10 [05:13<00:00, 31.30s/it]
